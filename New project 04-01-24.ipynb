# %% [markdown]
# ## My problem statement is:-The Chinese Spot Metal Prices data feed offers data on Chinese spot metal prices, including basic information and daily prices from Shanghai Gold Exchange. History goes back to February 2009, where available.

# %% [markdown]
# ### First  step is import some file which we want for this project

# %% [markdown]
# ###### In Python, Pandas is a widely used open-source data manipulation and analysis library. The alias pd is often used as a shorthand when importing the Pandas library. Here's why Pandas is commonly imported as pd:

# %%
import pandas as pd

# %% [markdown]
# in this step read the data which we want

# %%
data = pd.read_csv("DY-SMA.csv")

# %%
data
# Out:
#     commodity        date    open    high     low   close  change  \
# 0      AG9999  2017-12-28  3806.0  3806.0  3806.0  3806.0    40.0
# 1      AG9999  2017-12-27  3766.0  3766.0  3766.0  3766.0     6.0
# 2      AG9999  2017-12-26  3760.0  3760.0  3760.0  3760.0    54.0
# 3      AG9999  2017-12-22  3706.0  3706.0  3706.0  3706.0    -4.0
# 4      AG9999  2017-12-21  3710.0  3710.0  3710.0  3710.0     0.0
# ..        ...         ...     ...     ...     ...     ...     ...
# 530   IAU100G  2015-01-08   241.0   241.0   241.0   241.0     2.0
# 531    AG9999  2015-01-08  3530.0  3570.0  3530.0  3570.0     9.0
# 532    AG9999  2015-01-07  3530.0  3575.0  3530.0  3563.0    56.0
# 533    AG9999  2015-01-06  3474.0  3520.0  3473.0  3495.0    19.0
# 534    AG9999  2015-01-05  3475.0  3490.0  3454.0  3485.0     2.0
#
#      change_percent  weight_price  turnover_volume  turnover_value  \
# 0            0.0106        3806.0            600.0       2283600.0
# ...

# %% [markdown]
# In this step identify how many row and columns in this data

# %%
data.shape
# Out:
# (535, 14)

# %% [markdown]
# "shape" refers to the dimensions of a DataFrame or Series, representing the number of rows and columns.

# %% [markdown]
# Now we want to know the column names

# %%
data.columns
# Out:
# Index(['commodity', 'date', 'open', 'high', 'low', 'close', 'change',
#        'change_percent', 'weight_price', 'turnover_volume', 'turnover_value',
#        'open_interest', 'delivery_side', 'delivery_volume'],
#       dtype='object')

# %% [markdown]
# describe the data in this step

# %%
data.describe()
# Out:
#               open         high          low        close      change  \
# count   533.000000   533.000000   533.000000   533.000000  533.000000
# mean   2949.530994  2954.419606  2942.332195  2948.266829   -0.446529
# std    1455.524489  1457.136161  1453.018707  1454.832328   56.436647
# min     208.010000   208.010000   200.000000   208.000000 -394.000000
# 25%    3200.000000  3208.000000  3195.000000  3195.000000  -24.000000
# 50%    3505.000000  3523.000000  3500.000000  3516.000000   -0.390000
# 75%    3906.000000  3910.000000  3890.000000  3895.000000   18.000000
# max    4500.000000  4500.000000  4500.000000  4500.000000  380.000000
#
#        change_percent  weight_price  turnover_volume  turnover_value  \
# count      530.000000    533.000000     5.350000e+02    5.350000e+02
# mean         0.000475   2945.423621     1.842576e+04    1.535128e+07
# std          0.024792   1455.139732     3.283051e+05    3.044878e+07
# ...

# %% [markdown]
#  describe() method is used to generate descriptive statistics of a DataFrame or Series.

# %% [markdown]
# In this

# %%
data.count()
# Out:
# commodity          535
# date               535
# open               533
# high               533
# low                533
# close              533
# change             533
# change_percent     530
# weight_price       533
# turnover_volume    535
# turnover_value     535
# open_interest      417
# delivery_side        0
# delivery_volume      0
# dtype: int64

# %% [markdown]
#  count() method is used to count the number of non-null (non-missing) values in each column or Series of a DataFrame

# %%
data.isnull().sum()
# Out:
# commodity            0
# date                 0
# open                 2
# high                 2
# low                  2
# close                2
# change               2
# change_percent       5
# weight_price         2
# turnover_volume      0
# turnover_value       0
# open_interest      118
# delivery_side      535
# delivery_volume    535
# dtype: int64

# %% [markdown]
# isnull() function is used to identify missing or null values in a DataFrame or Series. It is a convenient method for checking whether each element in a DataFrame or Series is a null value or not.

# %%
data.isnull().mean()*100
# Out:
# commodity            0.000000
# date                 0.000000
# open                 0.373832
# high                 0.373832
# low                  0.373832
# close                0.373832
# change               0.373832
# change_percent       0.934579
# weight_price         0.373832
# turnover_volume      0.000000
# turnover_value       0.000000
# open_interest       22.056075
# delivery_side      100.000000
# delivery_volume    100.000000
# dtype: float64

# %%
data.shape
# Out:
# (535, 14)

# %%
df = [var for var in data.columns if data[var].isnull().mean()<0.05 and data[var].isnull().mean()>0]
df
# Out:
# ['open', 'high', 'low', 'close', 'change', 'change_percent', 'weight_price']

# %% [markdown]
# this code is for identity in which column there is null values are present

# %%
data[df].sample(5)
# Out:
#        open    high     low   close  change  change_percent  weight_price
# 361  3285.0  3285.0  3260.0  3284.0    -1.0         -0.0003       3284.00
# 509   257.5   257.5   255.0   257.0    -2.8         -0.0108        257.25
# 183  3948.0  3990.0  3948.0  3950.0  -394.0         -0.0907       3950.00
# 519   254.0   254.0   254.0   254.0     5.0          0.0201        254.00
# 522  3589.0  3589.0  3589.0  3589.0    33.0          0.0093       3589.00

# %%
len(data[df].dropna())/ len(data)
# Out:
# 0.9906542056074766

# %%
new_df = data[df].dropna()
new_df.shape
# Out:
# (530, 7)

# %%
new_df.head()
# Out:
#      open    high     low   close  change  change_percent  weight_price
# 0  3806.0  3806.0  3806.0  3806.0    40.0          0.0106        3806.0
# 1  3766.0  3766.0  3766.0  3766.0     6.0          0.0016        3766.0
# 2  3760.0  3760.0  3760.0  3760.0    54.0          0.0146        3760.0
# 3  3706.0  3706.0  3706.0  3706.0    -4.0         -0.0011        3706.0
# 4  3710.0  3710.0  3710.0  3710.0     0.0          0.0000        3710.0

# %% [markdown]
# is this stage all null values remove from original data

# %%
new_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 530 entries, 0 to 534
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   open            530 non-null    float64
#  1   high            530 non-null    float64
#  2   low             530 non-null    float64
#  3   close           530 non-null    float64
#  4   change          530 non-null    float64
#  5   change_percent  530 non-null    float64
#  6   weight_price    530 non-null    float64
# dtypes: float64(7)
# memory usage: 33.1 KB

# %% [markdown]
# this stpe for calculate duplicate value

# %%
sum(new_df.duplicated())
# Out:
# 2

# %%
new_df.drop_duplicates(inplace=True)

# %%
sum(new_df.duplicated())

# %%
import seaborn as sns
sns.set(color_codes = True)

# %% [markdown]
# Seaborn is a data visualization library based on Matplotlib that provides a high-level interface for drawing attractive and informative statistical graphics. Pandas is a powerful data manipulation library.

# %% [markdown]
# Now in this step we can identify any ouliers in this group

# %%
sns.distplot(new_df["open"])
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_15076\2043162286.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(new_df["open"])
# <Axes: xlabel='open', ylabel='Density'>

# %%
sns.boxplot(new_df["open"])

# %% [markdown]
#  There is no outliers in open column

# %%
sns.distplot(new_df["high"])
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_15076\4076389893.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(new_df["high"])
# <Axes: xlabel='high', ylabel='Density'>

# %%
sns.boxplot(new_df["high"])
# Out:
# <Axes: >

# %% [markdown]
# There is no outliers in high column

# %%
sns.distplot(new_df["weight_price"])
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_15076\1121019034.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(new_df["weight_price"])
# <Axes: xlabel='weight_price', ylabel='Density'>

# %%
sns.boxplot(new_df["weight_price"])
# Out:
# <Axes: >

# %%
sns.boxplot(new_df["change"])
# Out:
# <Axes: >

# %% [markdown]
# In this column there are some outliers

# %% [markdown]
# For the removing outliers i will use IQR method for Change column

# %% [markdown]
# #### IQR for remove outliers

# %%
q1 = new_df["change"].quantile(0.25)
q3 = new_df["change"].quantile(0.75)
iqr = q3-q1

# %%
q1 ,q3 , iqr
# Out:
# (-24.0, 18.0, 42.0)

# %%
upper_limit = q3 + (1.5* iqr)
lower_limit = q1 - (1.5* iqr)

# %%
lower_limit ,upper_limit
# Out:
# (-87.0, 81.0)

# %%
sns.boxplot(new_df["change"])
# Out:
# <Axes: >

# %%
new_df.loc[(new_df["change"] > upper_limit)|  (new_df["change"] < lower_limit)]
# Out:
#        open    high     low   close  change  change_percent  weight_price
# 25   3950.0  3950.0  3950.0  3950.0    82.0          0.0212        3950.0
# 53   3910.0  3910.0  3910.0  3910.0   126.0          0.0333        3910.0
# 70   3625.0  3625.0  3625.0  3625.0  -183.0         -0.0481        3625.0
# 72   3808.0  3808.0  3808.0  3808.0   -97.0         -0.0248        3808.0
# 79   3940.0  3940.0  3940.0  3940.0   -99.0         -0.0245        3940.0
# 96   4115.0  4115.0  4108.0  4108.0  -105.0         -0.0249        4111.0
# 106  4100.0  4100.0  4100.0  4100.0   105.0          0.0263        4100.0
# 115  4103.0  4103.0  4103.0  4103.0  -106.0         -0.0252        4103.0
# 118  4268.0  4268.0  4268.0  4268.0   128.0          0.0309        4268.0
# 148  3996.0  3996.0  3992.0  3992.0  -101.0         -0.0247        3992.0
# 150  4127.0  4127.0  4120.0  4123.0    88.0          0.0218        4123.0
# 156  4065.0  4065.0  4065.0  4065.0    99.0          0.0250        4065.0
# ...

# %%
#trimming (DELETE THE OUTLIERS)
df1 = new_df.loc[(new_df["change"]< upper_limit) &  (new_df["change"]> lower_limit)]
print("before removing outliers :", len(new_df))
print("after  removing outliers :", len(df1))
print("outliers :" , len(new_df) - len(df1))
# Out:
# before removing outliers : 528
# after  removing outliers : 473
# outliers : 55

# %%
sns.boxplot(df1["change"])
# Out:
# <Axes: >

# %% [markdown]
# Now this column is without outlier

# %% [markdown]
# Now in another column we will use zscore method for removing outlies

# %%
sns.distplot(new_df["change_percent"])
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_15076\2993093344.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(new_df["change_percent"])
# <Axes: xlabel='change_percent', ylabel='Density'>

# %%
sns.boxplot(new_df["change_percent"])
# Out:
# <Axes: >

# %% [markdown]
# we can see clearly in this column some are outliers

# %%
upper_limit = new_df["change_percent"].mean() + 3*new_df["change_percent"].std()
lower_limit = new_df["change_percent"].mean() - 3*new_df["change_percent"].std()
print("upper_limit:", upper_limit)
print("lower_limit:", lower_limit)
# Out:
# upper_limit: 0.074835801899055
# lower_limit: -0.07399678674753984

# %%
new_df.loc[(new_df["change_percent"] > upper_limit) | (new_df["change_percent"] < lower_limit)]
# Out:
#         open     high      low    close  change  change_percent  weight_price
# 121   273.00   273.00   273.00   273.00   27.99          0.1142        273.00
# 128   245.01   245.01   245.01   245.01  -20.99         -0.0789        245.01
# 171   278.00   278.00   278.00   278.00   37.00          0.1535        278.00
# 174   241.00   241.00   241.00   241.00  -34.00         -0.1236        241.00
# 177   275.00   275.00   275.00   275.00   25.00          0.1000        275.00
# 183  3948.00  3990.00  3948.00  3950.00 -394.00         -0.0907       3950.00
# 194   282.36   282.36   240.00   261.18  -21.35         -0.0756        261.18
# 197   280.00   283.80   280.00   282.53   25.53          0.0993        282.53
# 203   257.00   257.00   257.00   257.00  -28.00         -0.0983        257.00
# 225  4188.00  4188.00  4188.00  4188.00  380.00          0.0998       4188.00
# 226   287.00   290.00   287.00   290.00   24.90          0.0939        289.45
# ...

# %%
# in this column we will capping the outliers 
df1.copy()
df1.loc[df1["change_percent"]> upper_limit , "change_percent"] = upper_limit
df1.loc[df1["change_percent"]< lower_limit , "change_percent"] = lower_limit
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_15076\672259199.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1.loc[df1["change_percent"]> upper_limit , "change_percent"] = upper_limit
# C:\Users\hp\AppData\Local\Temp\ipykernel_15076\672259199.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1.loc[df1["change_percent"]< lower_limit , "change_percent"] = lower_limit

# %%
sns.boxplot(df1["change_percent"])
# Out:
# <Axes: >

# %% [markdown]
# in this menthod we were not trim data for delete data, we just cap it

# %% [markdown]
# # PAIR plot

# %%
sns.pairplot(df1)

# %% [markdown]
# : Pairplots are effective in visualizing relationships between multiple variables in a dataset. Each subplot in the grid represents a combination of two variables.

# %% [markdown]
# # Heat map
# ### Heatmaps are particularly useful for visualizing matrices or 2D data, where the color intensity represents the values in the matrix.Heatmaps make it easy to identify patterns and trends in complex datasets.

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize =(10,5))
df2 = df1.corr()
sns.heatmap(df2,cmap = "BrBG" , annot = True)
df2

# %% [markdown]
# #  Hence the above are some steps of the Exploratory datav analysis ,these are some general steps that you must follow in order to perform EDA . There are many more yet to come but for now ,this is more than enough idea as to perform a good EDA given any data sets .stay turned for more updates.
